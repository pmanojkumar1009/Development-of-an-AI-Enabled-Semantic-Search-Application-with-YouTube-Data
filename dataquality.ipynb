# %% [markdown]
# # Quality Check

# %%
pip install matplotlib seaborn isodate
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Collecting isodate
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Installing collected packages: isodate
# Successfully installed isodate-0.7.2

# %% [markdown]
# ## **Before cleaning**

# %%
import pandas as pd


transcripts_df = pd.read_csv("/content/all_transcripts.csv")
channel_details_df = pd.read_csv("/content/youtube_channel_videos_50.csv")

print("===== TRANSCRIPTS DATA =====")
print("Shape:", transcripts_df.shape)
print("\nInfo:")
print(transcripts_df.info())
print("\nMissing values:\n", transcripts_df.isnull().sum())
print("\nSample:\n", transcripts_df.head())

print("\n===== CHANNEL DETAILS DATA =====")
print("Shape:", channel_details_df.shape)
print("\nInfo:")
print(channel_details_df.info())
print("\nMissing values:\n", channel_details_df.isnull().sum())
print("\nSample:\n", channel_details_df.head())

print("\nNumerical Statistics:")
print(channel_details_df.describe())
# Out:
# ===== TRANSCRIPTS DATA =====
# Shape: (50, 2)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   video_id    50 non-null     object
#  1   transcript  50 non-null     object
# dtypes: object(2)
# memory usage: 932.0+ bytes
# None
#
# Missing values:
#  video_id      0
# transcript    0
# dtype: int64
#
# Sample:
#        video_id                                         transcript
# 0  7DKv5H5Frt0  This isn’t the standard\nYouTuber burnout-apol...
# 1  F0JDK_71yDg  The technical term\nfor these things is 'trans...
# 2  pU9sHwNKc2c  This video has been dubbed and subtitled\ninto...
# 3  LDiXNsWQzD0  I'm not allowed to climb this tower. I did ask...
# 4  jplrbxI5GN8  Do you remember that\ncontainer ship, the Ever...
#
# ===== CHANNEL DETAILS DATA =====
# Shape: (50, 22)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       50 non-null     object
#  1   title                    50 non-null     object
#  2   description              50 non-null     object
#  3   publishedAt              50 non-null     object
#  4   tags                     2 non-null      object
#  5   categoryId               50 non-null     int64
#  6   defaultLanguage          50 non-null     object
#  7   defaultAudioLanguage     50 non-null     object
#  8   thumbnail_default        50 non-null     object
#  9   thumbnail_high           50 non-null     object
#  10  duration                 50 non-null     object
#  11  viewCount                50 non-null     int64
#  12  likeCount                50 non-null     int64
#  13  commentCount             49 non-null     float64
#  14  privacyStatus            50 non-null     object
#  15  channel_id               50 non-null     object
#  16  channel_title            50 non-null     object
#  17  channel_description      50 non-null     object
#  18  channel_country          50 non-null     object
#  19  channel_thumbnail        50 non-null     object
#  20  channel_subscriberCount  50 non-null     int64
#  21  channel_videoCount       50 non-null     int64
# dtypes: float64(1), int64(5), object(16)
# memory usage: 8.7+ KB
# None
#
# Missing values:
#  id                          0
# title                       0
# description                 0
# publishedAt                 0
# tags                       48
# categoryId                  0
# defaultLanguage             0
# defaultAudioLanguage        0
# thumbnail_default           0
# thumbnail_high              0
# duration                    0
# viewCount                   0
# likeCount                   0
# commentCount                1
# privacyStatus               0
# channel_id                  0
# channel_title               0
# channel_description         0
# channel_country             0
# channel_thumbnail           0
# channel_subscriberCount     0
# channel_videoCount          0
# dtype: int64
#
# Sample:
#              id                                              title  \
# 0  7DKv5H5Frt0  After ten years, it's time to stop weekly videos.
# 1  F0JDK_71yDg         People are going to be angry about pylons.
# 2  pU9sHwNKc2c                 Why don't subtitles match dubbing?
# 3  LDiXNsWQzD0        Why use many streetlights when one will do?
# 4  jplrbxI5GN8            These tiny ships have a serious purpose
#
#                                          description           publishedAt  \
# 0  Find me here: ❓ LATERAL, free weekly podcast: ...  2024-01-01T16:00:06Z
# 1  Britain's power grid is turning inside-out, wh...  2023-12-25T16:00:08Z
# 2  Translation is really difficult. ■ AD: 👨‍💻 Nor...  2023-12-04T16:00:40Z
# 3  The moonlight towers of Austin, Texas, are the...  2023-11-27T16:00:13Z
# 4  At Port Iława in Poland, pilots and captains o...  2023-11-20T16:00:29Z
#
#                  tags  categoryId defaultLanguage defaultAudioLanguage  \
# 0  tom scott|tomscott          27              en                   en
# 1                 NaN          27              en                en-US
# 2  tom scott|tomscott          27              en                   en
# 3                 NaN          27              en                en-US
# 4                 NaN          27              en                en-US
#
#                                 thumbnail_default  \
# 0  https://i.ytimg.com/vi/7DKv5H5Frt0/default.jpg
# 1  https://i.ytimg.com/vi/F0JDK_71yDg/default.jpg
# 2  https://i.ytimg.com/vi/pU9sHwNKc2c/default.jpg
# 3  https://i.ytimg.com/vi/LDiXNsWQzD0/default.jpg
# 4  https://i.ytimg.com/vi/jplrbxI5GN8/default.jpg
#
#                                      thumbnail_high  ... likeCount  \
# 0  https://i.ytimg.com/vi/7DKv5H5Frt0/hqdefault.jpg  ...   1060600
# 1  https://i.ytimg.com/vi/F0JDK_71yDg/hqdefault.jpg  ...     92417
# 2  https://i.ytimg.com/vi/pU9sHwNKc2c/hqdefault.jpg  ...    109003
# 3  https://i.ytimg.com/vi/LDiXNsWQzD0/hqdefault.jpg  ...    129398
# 4  https://i.ytimg.com/vi/jplrbxI5GN8/hqdefault.jpg  ...     79136
#
#    commentCount  privacyStatus                channel_id channel_title  \
# 0       56646.0         public  UCBa659QWEk1AI4Tg--mrJ2A     Tom Scott
# 1        2650.0         public  UCBa659QWEk1AI4Tg--mrJ2A     Tom Scott
# 2        3798.0         public  UCBa659QWEk1AI4Tg--mrJ2A     Tom Scott
# 3        2831.0         public  UCBa659QWEk1AI4Tg--mrJ2A     Tom Scott
# 4        1781.0         public  UCBa659QWEk1AI4Tg--mrJ2A     Tom Scott
#
#                                  channel_description channel_country  \
# 0  Hi, I'm Tom Scott. These are some of the thing...              US
# 1  Hi, I'm Tom Scott. These are some of the thing...              US
# 2  Hi, I'm Tom Scott. These are some of the thing...              US
# 3  Hi, I'm Tom Scott. These are some of the thing...              US
# 4  Hi, I'm Tom Scott. These are some of the thing...              US
#
#                                    channel_thumbnail channel_subscriberCount  \
# 0  https://yt3.ggpht.com/1jXww-54zOdx2ksMQ2qDO-c7...                 6600000
# 1  https://yt3.ggpht.com/1jXww-54zOdx2ksMQ2qDO-c7...                 6600000
# 2  https://yt3.ggpht.com/1jXww-54zOdx2ksMQ2qDO-c7...                 6600000
# 3  https://yt3.ggpht.com/1jXww-54zOdx2ksMQ2qDO-c7...                 6600000
# 4  https://yt3.ggpht.com/1jXww-54zOdx2ksMQ2qDO-c7...                 6600000
#
#   channel_videoCount
# 0                731
# 1                731
# 2                731
# 3                731
# 4                731
#
# [5 rows x 22 columns]
#
# Numerical Statistics:
#        categoryId     viewCount     likeCount  commentCount  \
# count   50.000000  5.000000e+01  5.000000e+01     49.000000
# mean    26.760000  3.188527e+06  1.438012e+05   4589.000000
# std      1.697056  2.286206e+06  1.452878e+05   7799.880002
# min     15.000000  3.639790e+05  6.923000e+03   1079.000000
# 25%     27.000000  1.712330e+06  8.365725e+04   2001.000000
# 50%     27.000000  2.450356e+06  1.093485e+05   3154.000000
# 75%     27.000000  4.196500e+06  1.427710e+05   4217.000000
# max     27.000000  1.180963e+07  1.060600e+06  56646.000000
#
#        channel_subscriberCount  channel_videoCount
# count                     50.0                50.0
# mean                 6600000.0               731.0
# std                        0.0                 0.0
# min                  6600000.0               731.0
# 25%                  6600000.0               731.0
# 50%                  6600000.0               731.0
# 75%                  6600000.0               731.0
# max                  6600000.0               731.0

# %% [markdown]
# ## After **Cleaning**

# %%
import pandas as pd

transcripts_df = pd.read_csv("/content/all_transcripts.csv")
channel_details_df = pd.read_csv("/content/youtube_channel_videos_50.csv")

print("===== TRANSCRIPTS DATA =====")
print("Shape:", transcripts_df.shape)
print("\nInfo:")
print(transcripts_df.info())
print("\nMissing values:\n", transcripts_df.isnull().sum())
print("\nSample:\n", transcripts_df.head())

print("\n===== CHANNEL DETAILS DATA =====")
print("Shape:", channel_details_df.shape)
print("\nInfo:")
print(channel_details_df.info())
print("\nMissing values:\n", channel_details_df.isnull().sum())
print("\nSample:\n", channel_details_df.head())

channel_details_df["description"] = channel_details_df["description"].fillna("No description available")

if "tags" in channel_details_df.columns:
    channel_details_df = channel_details_df.drop(columns=["tags"])
    print("\n'Dropped tags column (all values missing)'")

print("\nAfter Cleaning - Missing values:\n", channel_details_df.isnull().sum())

print("\nNumerical Statistics:")
print(channel_details_df.describe())
# Out:
# ===== TRANSCRIPTS DATA =====
# Shape: (50, 2)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   video_id    50 non-null     object
#  1   transcript  50 non-null     object
# dtypes: object(2)
# memory usage: 932.0+ bytes
# None
#
# Missing values:
#  video_id      0
# transcript    0
# dtype: int64
#
# Sample:
#        video_id                                         transcript
# 0  7DKv5H5Frt0  This isn’t the standard\nYouTuber burnout-apol...
# 1  F0JDK_71yDg  The technical term\nfor these things is 'trans...
# 2  pU9sHwNKc2c  This video has been dubbed and subtitled\ninto...
# 3  LDiXNsWQzD0  I'm not allowed to climb this tower. I did ask...
# 4  jplrbxI5GN8  Do you remember that\ncontainer ship, the Ever...
#
# ===== CHANNEL DETAILS DATA =====
# Shape: (50, 22)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       50 non-null     object
#  1   title                    50 non-null     object
#  2   description              50 non-null     object
#  3   publishedAt              50 non-null     object
#  4   tags                     2 non-null      object
#  5   categoryId               50 non-null     int64
#  6   defaultLanguage          50 non-null     object
#  7   defaultAudioLanguage     50 non-null     object
#  8   thumbnail_default        50 non-null     object
#  9   thumbnail_high           50 non-null     object
#  10  duration                 50 non-null     object
#  11  viewCount                50 non-null     int64
#  12  likeCount                50 non-null     int64
#  13  commentCount             49 non-null     float64
#  14  privacyStatus            50 non-null     object
#  15  channel_id               50 non-null     object
#  16  channel_title            50 non-null     object
#  17  channel_description      50 non-null     object
#  18  channel_country          50 non-null     object
#  19  channel_thumbnail        50 non-null     object
#  20  channel_subscriberCount  50 non-null     int64
#  21  channel_videoCount       50 non-null     int64
# dtypes: float64(1), int64(5), object(16)
# memory usage: 8.7+ KB
# None
#
# Missing values:
#  id                          0
# title                       0
# description                 0
# publishedAt                 0
# tags                       48
# categoryId                  0
# defaultLanguage             0
# defaultAudioLanguage        0
# thumbnail_default           0
# thumbnail_high              0
# duration                    0
# viewCount                   0
# likeCount                   0
# commentCount                1
# privacyStatus               0
# channel_id                  0
# channel_title               0
# channel_description         0
# channel_country             0
# channel_thumbnail           0
# channel_subscriberCount     0
# channel_videoCount          0
# dtype: int64
#
# Sample:
#              id                                              title  \
# 0  7DKv5H5Frt0  After ten years, it's time to stop weekly videos.
# 1  F0JDK_71yDg         People are going to be angry about pylons.
# 2  pU9sHwNKc2c                 Why don't subtitles match dubbing?
# 3  LDiXNsWQzD0        Why use many streetlights when one will do?
# 4  jplrbxI5GN8            These tiny ships have a serious purpose
#
#                                          description           publishedAt  \
# 0  Find me here: ❓ LATERAL, free weekly podcast: ...  2024-01-01T16:00:06Z
# 1  Britain's power grid is turning inside-out, wh...  2023-12-25T16:00:08Z
# 2  Translation is really difficult. ■ AD: 👨‍💻 Nor...  2023-12-04T16:00:40Z
# 3  The moonlight towers of Austin, Texas, are the...  2023-11-27T16:00:13Z
# 4  At Port Iława in Poland, pilots and captains o...  2023-11-20T16:00:29Z
#
#                  tags  categoryId defaultLanguage defaultAudioLanguage  \
# 0  tom scott|tomscott          27              en                   en
# 1                 NaN          27              en                en-US
# 2  tom scott|tomscott          27              en                   en
# 3                 NaN          27              en                en-US
# 4                 NaN          27              en                en-US
#
#                                 thumbnail_default  \
# 0  https://i.ytimg.com/vi/7DKv5H5Frt0/default.jpg
# 1  https://i.ytimg.com/vi/F0JDK_71yDg/default.jpg
# 2  https://i.ytimg.com/vi/pU9sHwNKc2c/default.jpg
# 3  https://i.ytimg.com/vi/LDiXNsWQzD0/default.jpg
# 4  https://i.ytimg.com/vi/jplrbxI5GN8/default.jpg
#
#                                      thumbnail_high  ... likeCount  \
# 0  https://i.ytimg.com/vi/7DKv5H5Frt0/hqdefault.jpg  ...   1060600
# 1  https://i.ytimg.com/vi/F0JDK_71yDg/hqdefault.jpg  ...     92417
# 2  https://i.ytimg.com/vi/pU9sHwNKc2c/hqdefault.jpg  ...    109003
# 3  https://i.ytimg.com/vi/LDiXNsWQzD0/hqdefault.jpg  ...    129398
# 4  https://i.ytimg.com/vi/jplrbxI5GN8/hqdefault.jpg  ...     79136
#
#    commentCount  privacyStatus                channel_id channel_title  \
# 0       56646.0         public  UCBa659QWEk1AI4Tg--mrJ2A     Tom Scott
# 1        2650.0         public  UCBa659QWEk1AI4Tg--mrJ2A     Tom Scott
# 2        3798.0         public  UCBa659QWEk1AI4Tg--mrJ2A     Tom Scott
# 3        2831.0         public  UCBa659QWEk1AI4Tg--mrJ2A     Tom Scott
# 4        1781.0         public  UCBa659QWEk1AI4Tg--mrJ2A     Tom Scott
#
#                                  channel_description channel_country  \
# 0  Hi, I'm Tom Scott. These are some of the thing...              US
# 1  Hi, I'm Tom Scott. These are some of the thing...              US
# 2  Hi, I'm Tom Scott. These are some of the thing...              US
# 3  Hi, I'm Tom Scott. These are some of the thing...              US
# 4  Hi, I'm Tom Scott. These are some of the thing...              US
#
#                                    channel_thumbnail channel_subscriberCount  \
# 0  https://yt3.ggpht.com/1jXww-54zOdx2ksMQ2qDO-c7...                 6600000
# 1  https://yt3.ggpht.com/1jXww-54zOdx2ksMQ2qDO-c7...                 6600000
# 2  https://yt3.ggpht.com/1jXww-54zOdx2ksMQ2qDO-c7...                 6600000
# 3  https://yt3.ggpht.com/1jXww-54zOdx2ksMQ2qDO-c7...                 6600000
# 4  https://yt3.ggpht.com/1jXww-54zOdx2ksMQ2qDO-c7...                 6600000
#
#   channel_videoCount
# 0                731
# 1                731
# 2                731
# 3                731
# 4                731
#
# [5 rows x 22 columns]
#
# 'Dropped tags column (all values missing)'
#
# After Cleaning - Missing values:
#  id                         0
# title                      0
# description                0
# publishedAt                0
# categoryId                 0
# defaultLanguage            0
# defaultAudioLanguage       0
# thumbnail_default          0
# thumbnail_high             0
# duration                   0
# viewCount                  0
# likeCount                  0
# commentCount               1
# privacyStatus              0
# channel_id                 0
# channel_title              0
# channel_description        0
# channel_country            0
# channel_thumbnail          0
# channel_subscriberCount    0
# channel_videoCount         0
# dtype: int64
#
# Numerical Statistics:
#        categoryId     viewCount     likeCount  commentCount  \
# count   50.000000  5.000000e+01  5.000000e+01     49.000000
# mean    26.760000  3.188527e+06  1.438012e+05   4589.000000
# std      1.697056  2.286206e+06  1.452878e+05   7799.880002
# min     15.000000  3.639790e+05  6.923000e+03   1079.000000
# 25%     27.000000  1.712330e+06  8.365725e+04   2001.000000
# 50%     27.000000  2.450356e+06  1.093485e+05   3154.000000
# 75%     27.000000  4.196500e+06  1.427710e+05   4217.000000
# max     27.000000  1.180963e+07  1.060600e+06  56646.000000
#
#        channel_subscriberCount  channel_videoCount
# count                     50.0                50.0
# mean                 6600000.0               731.0
# std                        0.0                 0.0
# min                  6600000.0               731.0
# 25%                  6600000.0               731.0
# 50%                  6600000.0               731.0
# 75%                  6600000.0               731.0
# max                  6600000.0               731.0
